# %% [markdown]
# <a href="https://colab.research.google.com/github/Dzikri-FHakim/sistem-panen-dzikri/blob/konflik-dzikrii/update_harga.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# kalkulator_harga.py

nama_produk = "Kopi Susu"
harga = 15000 # Harga normal di branch main

def tampilkan_harga():
    print(f"Harga {nama_produk} saat ini adalah Rp{harga}")

tampilkan_harga()
# Out:
# Harga Kopi Susu saat ini adalah Rp15000
